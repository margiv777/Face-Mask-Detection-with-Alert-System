# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from imutils.video import VideoStream
from tensorflow import keras
import tensorflow as tf
import numpy as np
import imutils
import time
import cv2
import os
# for sending email
import smtplib
from email.message import EmailMessage
import time
import threading
import datetime

# %%
# at last rmove >>>------- comment line
def detect_and_predict_mask(frame, faceNet, maskNet):
    # grab the dimensions of the frame and then construct a blob
    # from it
    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 1.0, (224, 224),
        (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the face detections
    faceNet.setInput(blob)
    detections = faceNet.forward()
#>>>-------     print(detections.shape)

    # initialize our list of faces, their corresponding locations,
    # and the list of predictions from our face mask network
    faces = []
    locs = []
    preds = []

    # loop over the detections
    for i in range(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with
        # the detection
        confidence = detections[0, 0, i, 2]

        # filter out weak detections by ensuring the confidence is
        # greater than the minimum confidence
        if confidence > 0.5:
            # compute the (x, y)-coordinates of the bounding box for
            # the object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # ensure the bounding boxes fall within the dimensions of
            # the frame
            (startX, startY) = (max(0, startX), max(0, startY))
            (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

            # extract the face ROI, convert it from BGR to RGB channel
            # ordering, resize it to 224x224, and preprocess it
            face = frame[startY:endY, startX:endX]
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)

            # add the face and bounding boxes to their respective
            # lists
            faces.append(face)
            locs.append((startX, startY, endX, endY))

    # only make a predictions if at least one face was detected
    if len(faces) > 0:
        # for faster inference we'll make batch predictions on *all*
        # faces at the same time rather than one-by-one predictions
        # in the above `for` loop
        faces = np.array(faces, dtype="float32")
        preds = maskNet.predict(faces, batch_size=32)
#>>>-------         print(preds)

    # return a 2-tuple of the face locations and their corresponding
    # locations
    return (locs, preds)

# %%
# load our serialized face detector model from disk
prototxtPath = r"face_detector\deploy.prototxt"
weightsPath = r"face_detector\res10_300x300_ssd_iter_140000.caffemodel"
faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)

# %%
# load the face mask detector model from disk
recogNet = load_model(r"model\face_recog_ak_dh_sh_mar_4class.model")
maskNet = load_model(r"model\mask_detector_final.model")

# %%
# for sending email alert
def email_alert(subject,body, to):
    msg=EmailMessage()
    msg.set_content(body)
    msg['subject'] = subject
    msg['to'] = to
    user= "alert7359@gmail.com"
    msg['from']= user
    password="dgdupzeguzfythet"
    
    server = smtplib.SMTP("smtp.gmail.com", 587)
    server.starttls()
    server.login(user,password)
    server.send_message(msg)
    
    server.quit()

# %%
# threading..

total_count=0
count={"akshit":0,"shital":0,"dhruvil":0,"margiv":0}
flag={"akshit":0,"shital":0,"dhruvil": 0,"margiv":0}
detect={"akshit":0,"shital":0,"dhruvil":0,"margiv":0}
to={"akshit":"19ce022@charusat.edu.in","shital":"charusat.edu.in","dhruvil":"@charusat.edu.in","margiv":"19ce002@charusat.edu.in"}
subject="COVID-19 Mask Rule Violated by YOU!"
body="Dear Student,\nYou have been found violating rule by not wearning a mask! Pleasure ensure safety protocol is being folllowed by you."


def decrease_time(rec):
    print("\n"+str(rec) +" is released...\n")
    detect[rec]=0
    flag[rec]=0
def speak_message(audio):
    engine.say(audio)
    engine.runAndWait()

def message(rec):
    if flag[rec]==0 :  # message yet not send
        current_time=datetime.datetime.now().strftime("%H:%M:%S") 
        print("\nmessage sent to " + rec+".... at "+ str(current_time))

#         email_alert(subject,body,to[rec])
    
        flag[rec]=1
        count[rec]+=1
        detect[rec]=0
        delay=180                    #second
        thread_start=threading.Timer(delay,decrease_time,[rec])
        thread_start.start()
        
        
def call_message(rec):
    if flag[rec]==0:
        message(rec)

# %%
flag,count
# Out:
# ({'akshit': 0, 'shital': 0, 'dhruvil': 0, 'margiv': 0},
#  {'akshit': 0, 'shital': 0, 'dhruvil': 0, 'margiv': 0})

# %%
def recog_face(frame,faceNet,recogNet):
    # detect faces in the frame and determine if they are wearing a
    # face mask or no
    (locs, preds) = detect_and_predict_mask(frame, faceNet,recogNet)
    # loop over the detected face locations and their corresponding
    # locations
    for (box, pred) in zip(locs, preds):
        # unpack the bounding box and predictions
        (startX, startY, endX, endY) = box
        (akshit,dhruvil,margiv,shital) = pred

# determine the class label and color we'll use to draw
        # the bounding box and text
        if akshit>0.80:
            label="akshit"
        elif dhruvil>0.80:
            label="dhruvil"
        elif margiv>0.80:
            label="margiv"
        elif shital>0.80:
            label="shital"
        else:
            label="Not Found"
        
        if label != "Not Found": 
            detect[label]+=1
            if detect[label]>15:
    #             print(label+" is fouded for"+ str(detect[label])+" time")
                call_message(label)
        
            print(label+" is fouded for"+ str(detect[label])+" time")
            
        
# label = "Mask" if akshit >  else "No Mask"
# color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

        # include the probability in the label
        label = "{}: {:.2f}%".format(label, max(akshit,dhruvil,margiv,shital) * 100)
        return label

# %%
# initialize the video stream
print("[INFO] starting video stream...")
vs = VideoStream(src=0).start()

# loop over the frames from the video stream
while True:
    # grab the frame from the threaded video stream and resize it
    # to have a maximum width of 400 pixels
    frame = vs.read()
    frame = imutils.resize(frame, width=600)

    # detect faces in the frame and determine if they are wearing a
    # face mask or not
    (locs, preds) = detect_and_predict_mask(frame, faceNet, maskNet)

    # loop over the detected face locations and their corresponding
    # locations
    for (box, pred) in zip(locs, preds):
        # unpack the bounding box and predictions
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred

# determine the class label and color we'll use to draw
# the bounding box and text
        label1 = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label1 == "Mask" else (0, 0, 255)
        
        if label1=="No Mask":
            label_recog=recog_face(frame,faceNet,recogNet)
            cv2.putText(frame, label_recog, (startX, endY +15),cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 0), 2)
       
        # include the probability in the label
        label1 = "{}: {:.2f}%".format(label1, max(mask, withoutMask) * 100)
    
        # display the label and bounding box rectangle on the output
        # frame
        cv2.putText(frame, label1, (startX, startY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

    # show the output frame
        cv2.imshow("Frame", frame)
#     key = cv2.waitKey(1) & 0xFF

    # if the `q` key was pressed, break from the loop
    if cv2.waitKey(10) == ord('q'):
        break

# do a bit of cleanup
cv2.destroyAllWindows()
vs.stop()
# Out:
# [INFO] starting video stream...
# margiv is fouded for1 time
# margiv is fouded for2 time
# margiv is fouded for3 time
# margiv is fouded for4 time
# margiv is fouded for5 time
# margiv is fouded for6 time
# dhruvil is fouded for1 time
# margiv is fouded for7 time
# margiv is fouded for8 time
# margiv is fouded for9 time
# margiv is fouded for10 time
# margiv is fouded for11 time
# dhruvil is fouded for2 time
# akshit is fouded for1 time
# akshit is fouded for2 time
# akshit is fouded for3 time
# margiv is fouded for12 time
# akshit is fouded for4 time
# margiv is fouded for13 time
# dhruvil is fouded for3 time
# margiv is fouded for14 time
# margiv is fouded for15 time
#
# message sent to margiv.... at 18:09:06
# margiv is fouded for0 time
# margiv is fouded for1 time
# margiv is fouded for2 time
# margiv is fouded for3 time
# margiv is fouded for4 time
# margiv is fouded for5 time
# margiv is fouded for6 time
# margiv is fouded for7 time
# margiv is fouded for8 time
# margiv is fouded for9 time
# margiv is fouded for10 time
# shital is fouded for1 time
# margiv is fouded for11 time
# margiv is fouded for12 time
# margiv is fouded for13 time
# margiv is fouded for14 time
# margiv is fouded for15 time
# margiv is fouded for16 time
# margiv is fouded for17 time
# margiv is fouded for18 time
# margiv is fouded for19 time
# margiv is fouded for20 time
# margiv is fouded for21 time
# margiv is fouded for22 time
# margiv is fouded for23 time
# margiv is fouded for24 time
# margiv is fouded for25 time
# margiv is fouded for26 time
# margiv is fouded for27 time
# margiv is fouded for28 time
# margiv is fouded for29 time
# margiv is fouded for30 time
# margiv is fouded for31 time
# margiv is fouded for32 time
# margiv is fouded for33 time
# margiv is fouded for34 time
# dhruvil is fouded for4 time
# dhruvil is fouded for5 time
# margiv is fouded for35 time
# margiv is fouded for36 time
# margiv is fouded for37 time
# margiv is fouded for38 time
# margiv is fouded for39 time
# margiv is fouded for40 time
# margiv is fouded for41 time
# margiv is fouded for42 time
# margiv is fouded for43 time
# margiv is fouded for44 time
# margiv is fouded for45 time
# margiv is fouded for46 time
# margiv is fouded for47 time
# margiv is fouded for48 time
# margiv is fouded for49 time
# margiv is fouded for50 time
# margiv is fouded for51 time
# margiv is fouded for52 time
# margiv is fouded for53 time
# margiv is fouded for54 time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1f24266eb1d4> in <module>
#      43
#      44     # if the `q` key was pressed, break from the loop
# ---> 45     if cv2.waitKey(10) == ord('q'):
#      46         break
#      47
#
# KeyboardInterrupt:

# %%
count
# Out:
# {'akshit': 1, 'shital': 0, 'dhruvil': 0, 'margiv': 0}

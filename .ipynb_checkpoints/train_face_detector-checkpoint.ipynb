# %%
# import the necessary packages
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LR = 0.001
EPOCHS = 25
BS = 32

# %%
DIRECTORY = r"C:\Users\Akshit\SGP\ML Mask Detection\dataset"
CATEGORIES = ["akshit","dhruvil","shital","margiv"]

# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")

data = []
labels = []
real_img=[]

for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        image = load_img(img_path, target_size=(224, 224))
        real_img.append(image)
        image = img_to_array(image)
        image = preprocess_input(image)

        data.append(image)
        labels.append(category)
print('task completed')
# Out:
# [INFO] loading images...
# task completed

# %%
i=700
print(plt.imshow(real_img[i]))
print(labels[i])
# Out:
# AxesImage(54,36;334.8x217.44)
# [0. 1. 0. 0.]

# %%
# perform one-hot encoding on the labels
le = LabelEncoder() 
  
new_label=le.fit_transform(labels) 
labels=to_categorical(new_label)

# %%
i=2000
print(plt.imshow(real_img[i]))
print(new_label[i])
print(labels[i])
# Out:
# AxesImage(54,36;334.8x217.44)
# 2
# [0. 0. 1. 0.]

# %% [markdown]
# data = np.array(data, dtype="float32")
# labels = np.array(labels)
#
# (trainX, testX, trainY, testY) = train_test_split(data, labels,test_size=0.20, stratify=labels, random_state=42)

# %%
# construct the training image generator for data augmentation
aug = ImageDataGenerator(rotation_range=20,zoom_range=0.30,
                         width_shift_range=0.2,height_shift_range=0.2,
                         shear_range=0.15,horizontal_flip=True,
                         vertical_flip=True,fill_mode="nearest")

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are
# left off
baseModel = MobileNetV2(weights="imagenet", include_top=False,alpha=1.0,
                        input_tensor=Input(shape=(224, 224, 3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
# construct the head of the model that will be placed on top of the
# the base model
#We will then build the last fully-connected layer.
headModel=baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7),data_format=None,
                             padding='valid')(headModel)
#Flatten the output of our base model to 1 dimension
headModel = Flatten(name="flatten")(headModel)
# Add a fully connected layer with 128 hidden units and ReLU activation
headModel = Dense(128, activation="relu")(headModel)
#Add dropout rate of 0.5 
headModel = Dropout(0.5)(headModel)
# Add a final softmax layer for classification
headModel = Dense(4, activation="softmax")(headModel)

# %%
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process

#We should also prevent the weights of the convolution from being updated 
#before the model is compiled and trained. To do this we set the trainable 
#attribute to false.
for layer in baseModel.layers:
    layer.trainable = False

# compile our model
print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
    metrics=["accuracy"])
print("finished compiling")
# Out:
# [INFO] compiling model...
# finished compiling

# %%
# train the head of the network
print("[INFO] training head...")
H = model.fit(aug.flow(trainX, trainY, batch_size=BS),
              steps_per_epoch=len(trainX) // BS,
              validation_data=(testX, testY),
              validation_steps=len(testX) // BS,
              epochs=EPOCHS)
# Out:
# [INFO] training head...
# Epoch 1/25
# 63/63 [==============================] - 128s 2s/step - loss: 0.7590 - accuracy: 0.7240 - val_loss: 0.0361 - val_accuracy: 0.9980
# Epoch 2/25
# 63/63 [==============================] - 116s 2s/step - loss: 0.0608 - accuracy: 0.9848 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 3/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0366 - accuracy: 0.9895 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 4/25
# 63/63 [==============================] - 112s 2s/step - loss: 0.0331 - accuracy: 0.9876 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 5/25
# 63/63 [==============================] - 112s 2s/step - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 6/25
# 63/63 [==============================] - 176s 3s/step - loss: 0.0104 - accuracy: 0.9986 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 7/25
# 63/63 [==============================] - 100s 2s/step - loss: 0.0124 - accuracy: 0.9982 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 8/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0228 - accuracy: 0.9911 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 9/25
# 63/63 [==============================] - 115s 2s/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 8.6010e-04 - val_accuracy: 1.0000
# Epoch 10/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0072 - accuracy: 0.9995 - val_loss: 4.4132e-04 - val_accuracy: 1.0000
# Epoch 11/25
# 63/63 [==============================] - 112s 2s/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 3.5982e-04 - val_accuracy: 1.0000
# Epoch 12/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0204 - accuracy: 0.9914 - val_loss: 4.2656e-04 - val_accuracy: 1.0000
# Epoch 13/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0239 - accuracy: 0.9955 - val_loss: 1.8977e-04 - val_accuracy: 1.0000
# Epoch 14/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 1.9822e-04 - val_accuracy: 1.0000
# Epoch 15/25
# 63/63 [==============================] - 113s 2s/step - loss: 0.0150 - accuracy: 0.9959 - val_loss: 3.2339e-04 - val_accuracy: 1.0000
# Epoch 16/25
# 63/63 [==============================] - 114s 2s/step - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 17/25
# 63/63 [==============================] - 121s 2s/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 1.0769e-04 - val_accuracy: 1.0000
# Epoch 18/25
# 63/63 [==============================] - 97s 2s/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 7.0499e-05 - val_accuracy: 1.0000
# Epoch 19/25
# 63/63 [==============================] - 120s 2s/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 2.3942e-04 - val_accuracy: 1.0000
# Epoch 20/25
# 63/63 [==============================] - 116s 2s/step - loss: 0.0041 - accuracy: 0.9999 - val_loss: 9.6225e-05 - val_accuracy: 1.0000
# Epoch 21/25
# 63/63 [==============================] - 115s 2s/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 8.4989e-04 - val_accuracy: 1.0000
# Epoch 22/25
# 63/63 [==============================] - 112s 2s/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 9.9205e-04 - val_accuracy: 1.0000
# Epoch 23/25
# 63/63 [==============================] - 113s 2s/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 1.1571e-04 - val_accuracy: 1.0000
# Epoch 24/25
# 63/63 [==============================] - 113s 2s/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 4.9623e-05 - val_accuracy: 1.0000
# Epoch 25/25
# 63/63 [==============================] - 118s 2s/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 6.4238e-05 - val_accuracy: 1.0000

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
prediction = model.predict(testX, batch_size=BS)
# Out:
# [INFO] evaluating network...

# %%
print(prediction.shape)
prediction
# Out:
# (512, 4)
# array([[1.5244431e-06, 1.4735795e-10, 9.9999845e-01, 2.7388390e-08],
#        [2.6542664e-05, 3.8506425e-08, 9.9996603e-01, 7.3331144e-06],
#        [9.3056024e-06, 9.9999070e-01, 4.5328896e-09, 2.8126315e-08],
#        ...,
#        [2.2385512e-04, 9.9977583e-01, 4.0733812e-07, 9.6116493e-09],
#        [3.6817828e-06, 3.6471118e-08, 9.9999440e-01, 1.8835093e-06],
#        [3.6186844e-08, 4.5943246e-10, 9.9999893e-01, 1.0498022e-06]],
#       dtype=float32)

# %%
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(prediction, axis=1)
print(predIdxs.shape)
predIdxs
# Out:
# (512,)
# array([2, 2, 1, 2, 3, 3, 2, 3, 2, 2, 0, 2, 2, 1, 0, 0, 2, 2, 0, 3, 0, 3,
#        2, 2, 2, 1, 3, 1, 2, 0, 0, 3, 1, 3, 1, 0, 3, 2, 3, 3, 1, 2, 3, 0,
#        1, 1, 2, 2, 1, 2, 3, 0, 2, 1, 0, 2, 2, 3, 2, 2, 2, 2, 2, 3, 0, 3,
#        2, 2, 0, 3, 3, 2, 2, 1, 1, 0, 3, 0, 1, 3, 2, 1, 1, 3, 2, 3, 3, 3,
#        1, 1, 2, 2, 1, 2, 0, 1, 0, 0, 2, 0, 0, 0, 2, 1, 1, 3, 3, 1, 2, 2,
#        1, 2, 2, 1, 2, 2, 3, 2, 2, 1, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 2, 0,
#        3, 3, 1, 1, 3, 3, 1, 3, 2, 0, 2, 2, 3, 1, 2, 0, 0, 3, 0, 0, 2, 2,
#        0, 3, 2, 0, 0, 1, 0, 0, 3, 0, 2, 2, 1, 1, 2, 0, 2, 2, 3, 2, 3, 3,
#        2, 2, 3, 3, 3, 1, 3, 1, 2, 1, 0, 0, 1, 2, 3, 2, 3, 2, 3, 2, 2, 2,
#        2, 2, 0, 2, 2, 0, 2, 2, 0, 3, 1, 1, 3, 3, 2, 2, 2, 3, 2, 2, 2, 2,
#        2, 3, 3, 1, 2, 2, 0, 3, 2, 0, 2, 2, 3, 2, 3, 2, 1, 2, 1, 3, 1, 3,
#        3, 2, 3, 2, 0, 2, 2, 1, 2, 2, 1, 0, 2, 3, 1, 1, 2, 1, 0, 0, 3, 1,
#        2, 3, 0, 1, 2, 2, 2, 0, 1, 2, 0, 2, 3, 1, 0, 2, 0, 0, 2, 2, 1, 3,
#        2, 2, 2, 3, 0, 3, 1, 0, 2, 2, 2, 3, 1, 2, 0, 2, 3, 2, 2, 1, 2, 0,
#        3, 3, 2, 1, 3, 0, 3, 2, 2, 3, 2, 1, 1, 1, 3, 2, 1, 3, 0, 0, 2, 3,
#        1, 2, 2, 0, 2, 0, 0, 0, 0, 2, 2, 3, 2, 3, 0, 1, 2, 2, 0, 2, 3, 2,
#        0, 0, 1, 3, 3, 3, 3, 2, 0, 2, 1, 1, 2, 0, 1, 3, 2, 2, 0, 2, 3, 0,
#        1, 0, 3, 2, 2, 1, 2, 0, 0, 2, 1, 1, 0, 2, 2, 0, 0, 0, 2, 2, 2, 1,
#        1, 0, 2, 1, 1, 2, 1, 3, 3, 2, 1, 1, 3, 2, 0, 3, 3, 2, 0, 2, 3, 0,
#        1, 0, 2, 2, 2, 3, 0, 3, 1, 1, 3, 2, 3, 2, 3, 2, 1, 2, 1, 2, 2, 2,
#        3, 3, 2, 2, 2, 3, 1, 0, 2, 2, 3, 3, 0, 2, 2, 0, 2, 0, 0, 0, 2, 1,
#        0, 2, 2, 2, 3, 0, 1, 0, 1, 3, 3, 1, 2, 3, 3, 2, 2, 0, 2, 1, 0, 0,
#        3, 3, 2, 1, 2, 2, 3, 2, 0, 3, 2, 2, 2, 3, 0, 2, 3, 0, 2, 0, 1, 2,
#        3, 3, 2, 1, 2, 2], dtype=int64)

# %%
# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,
    target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#       akshit       1.00      1.00      1.00       100
#      dhruvil       1.00      1.00      1.00        92
#       margiv       1.00      1.00      1.00       200
#       shital       1.00      1.00      1.00       120
#
#     accuracy                           1.00       512
#    macro avg       1.00      1.00      1.00       512
# weighted avg       1.00      1.00      1.00       512

# %%
# serialize the model to disk
print("saving mask detector model...")
model.save("face_recog_ak_dh_sh_mar_4class.model", save_format="h5")
# Out:
# saving mask detector model...

# %%
# plot the loss
N = EPOCHS
plt.figure(dpi=120)
plt.plot(range(0, N), H.history["loss"], label="Train_loss")
plt.plot(range(0,N),H.history["val_loss"], label="val_Loss")
plt.title("Training Loss")
plt.xlabel("Epoch ")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.show()

# %%
# plot the accuracy
N = EPOCHS
plt.figure(dpi=120)
plt.plot(range(0, N), H.history["accuracy"], label="Train_Accuracy")
plt.plot(range(0,N),H.history["val_accuracy"], label="val_Accuracy")
plt.title("Training Accuracy")
plt.xlabel("Epoch ")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()
